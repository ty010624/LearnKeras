# %% [markdown]
# Simple MNIST convnet
# https://keras.io/examples/vision/mnist_convnet/

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

print(tf.__version__)
# Out:
# 2.6.0

# %%
# Model / data parameters
num_classes = 10
input_shape = (28, 28, 1)

# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# Scale images to the [0, 1] range
x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255
# Make sure images have shape (28, 28, 1)
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)
print("x_train shape:", x_train.shape)
print(x_train.shape[0], "train samples")
print(x_test.shape[0], "test samples")


# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %%
model = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        layers.Conv2D(32, kernel_size=(3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Conv2D(64, kernel_size=(3, 3), activation="relu"),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Flatten(),
        layers.Dropout(0.5),
        layers.Dense(num_classes, activation="softmax"),
    ]
)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 11, 11, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1600)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1600)              0
# _________________________________________________________________
# dense (Dense)                (None, 10)                16010
# =================================================================
# Total params: 34,826
# Trainable params: 34,826
# Non-trainable params: 0
# _________________________________________________________________

# %%
batch_size = 128
epochs = 15

model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.1)
# Out:
# Epoch 1/15
# 422/422 [==============================] - 8s 7ms/step - loss: 0.3664 - accuracy: 0.8898 - val_loss: 0.0832 - val_accuracy: 0.9773
# Epoch 2/15
# 422/422 [==============================] - 2s 6ms/step - loss: 0.1110 - accuracy: 0.9661 - val_loss: 0.0570 - val_accuracy: 0.9845
# Epoch 3/15
# 422/422 [==============================] - 2s 6ms/step - loss: 0.0828 - accuracy: 0.9753 - val_loss: 0.0494 - val_accuracy: 0.9868
# Epoch 4/15
# 422/422 [==============================] - 2s 6ms/step - loss: 0.0690 - accuracy: 0.9789 - val_loss: 0.0448 - val_accuracy: 0.9880
# Epoch 5/15
# 422/422 [==============================] - 2s 6ms/step - loss: 0.0625 - accuracy: 0.9807 - val_loss: 0.0387 - val_accuracy: 0.9898
# Epoch 6/15
# 422/422 [==============================] - 2s 6ms/step - loss: 0.0571 - accuracy: 0.9830 - val_loss: 0.0366 - val_accuracy: 0.9897
# Epoch 7/15
# 422/422 [==============================] - 2s 6ms/step - loss: 0.0505 - accuracy: 0.9837 - val_loss: 0.0360 - val_accuracy: 0.9910
# Epoch 8/15
# 422/422 [==============================] - 2s 6ms/step - loss: 0.0477 - accuracy: 0.9851 - val_loss: 0.0362 - val_accuracy: 0.9905
# Epoch 9/15
# 422/422 [==============================] - 2s 6ms/step - loss: 0.0442 - accuracy: 0.9854 - val_loss: 0.0352 - val_accuracy: 0.9905
# Epoch 10/15
# 422/422 [==============================] - 2s 6ms/step - loss: 0.0419 - accuracy: 0.9863 - val_loss: 0.0324 - val_accuracy: 0.9905
# Epoch 11/15
# 422/422 [==============================] - 2s 6ms/step - loss: 0.0382 - accuracy: 0.9877 - val_loss: 0.0306 - val_accuracy: 0.9920
# Epoch 12/15
# 422/422 [==============================] - 2s 6ms/step - loss: 0.0380 - accuracy: 0.9882 - val_loss: 0.0311 - val_accuracy: 0.9908
# Epoch 13/15
# 422/422 [==============================] - 2s 6ms/step - loss: 0.0364 - accuracy: 0.9883 - val_loss: 0.0290 - val_accuracy: 0.9922
# Epoch 14/15
# 422/422 [==============================] - 2s 6ms/step - loss: 0.0343 - accuracy: 0.9891 - val_loss: 0.0280 - val_accuracy: 0.9927
# Epoch 15/15
# 422/422 [==============================] - 2s 6ms/step - loss: 0.0319 - accuracy: 0.9897 - val_loss: 0.0291 - val_accuracy: 0.9918

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# Test loss: 0.023208443075418472
# Test accuracy: 0.9926999807357788
